# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from scipy.io import wavfile
from scipy import signal as sig

# %%
parent = Path('.').resolve().parent
folder_path = parent / "resources/diffuser_meas"

nbinarni_folder = sorted(Path(folder_path / "nbinarni").iterdir())
plyta_folder = sorted(Path(folder_path / "plyta").iterdir())
pusta_folder = sorted(Path(folder_path / "pusta").iterdir())

def import_waves_from_folder_to_array(folder):
    ans_list = []
    sr_mem = None
    for file in folder:
        sr, data = wavfile.read(file)
        if (sr_mem and sr != sr_mem ):
            x = np.linspace(0, 1, 100)
            plt.plot(x, np.sin(np.exp(x)))
            plt.title(f"error inconsistent sample rate in {str(file)}")
            plt.show()
            print("error inconsistent sample rate")
        sr_mem = sr
        ans_list.append(data)
    return sr, ans_list

# sr, nbinarni_angles = import_waves_from_folder_to_array(nbinarni_folder)
sr, plyta_angles = import_waves_from_folder_to_array(plyta_folder)
# sr, pusta_angles = import_waves_from_folder_to_array(pusta_folder)

# print(plyta_angles[0])
s = plyta_angles[0]
time = len(s)/ sr
print(time)
timewekt = np.linspace(0, time-1/sr, len(s))
# mask = 
plt.plot(timewekt, s[:,0])
plt.show()


#UWAGA NIE LICZYMY RMS W PUNKCIE 5
# Out:
# [PosixPath('/Users/janek/Local/Python_Projects/AGH_quests/resources/diffuser_meas/nbinarni/ir_lab__0.wav'), PosixPath('/Users/janek/Local/Python_Projects/AGH_quests/resources/diffuser_meas/nbinarni/ir_lab__1.wav'), PosixPath('/Users/janek/Local/Python_Projects/AGH_quests/resources/diffuser_meas/nbinarni/ir_lab__10.wav'), PosixPath('/Users/janek/Local/Python_Projects/AGH_quests/resources/diffuser_meas/nbinarni/ir_lab__11.wav'), PosixPath('/Users/janek/Local/Python_Projects/AGH_quests/resources/diffuser_meas/nbinarni/ir_lab__12.wav'), PosixPath('/Users/janek/Local/Python_Projects/AGH_quests/resources/diffuser_meas/nbinarni/ir_lab__13.wav'), PosixPath('/Users/janek/Local/Python_Projects/AGH_quests/resources/diffuser_meas/nbinarni/ir_lab__14.wav'), PosixPath('/Users/janek/Local/Python_Projects/AGH_quests/resources/diffuser_meas/nbinarni/ir_lab__15.wav'), PosixPath('/Users/janek/Local/Python_Projects/AGH_quests/resources/diffuser_meas/nbinarni/ir_lab__16.wav'), PosixPath('/Users/janek/Local/Python_Projects/AGH_quests/resources/diffuser_meas/nbinarni/ir_lab__17.wav'), PosixPath('/Users/janek/Local/Python_Projects/AGH_quests/resources/diffuser_meas/nbinarni/ir_lab__18.wav'), PosixPath('/Users/janek/Local/Python_Projects/AGH_quests/resources/diffuser_meas/nbinarni/ir_lab__2.wav'), PosixPath('/Users/janek/Local/Python_Projects/AGH_quests/resources/diffuser_meas/nbinarni/ir_lab__3.wav'), PosixPath('/Users/janek/Local/Python_Projects/AGH_quests/resources/diffuser_meas/nbinarni/ir_lab__4.wav'), PosixPath('/Users/janek/Local/Python_Projects/AGH_quests/resources/diffuser_meas/nbinarni/ir_lab__5.wav'), PosixPath('/Users/janek/Local/Python_Projects/AGH_quests/resources/diffuser_meas/nbinarni/ir_lab__6.wav'), PosixPath('/Users/janek/Local/Python_Projects/AGH_quests/resources/diffuser_meas/nbinarni/ir_lab__7.wav'), PosixPath('/Users/janek/Local/Python_Projects/AGH_quests/resources/diffuser_meas/nbinarni/ir_lab__8.wav'), PosixPath('/Users/janek/Local/Python_Projects/AGH_quests/resources/diffuser_meas/nbinarni/ir_lab__9.wav')] xxx
#
# 1.0
